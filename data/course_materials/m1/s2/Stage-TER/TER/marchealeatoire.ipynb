# %%
import numpy as np
import matplotlib.pyplot as plt

def marche_aleatoire(p, alpha, steps, simulations):
    survivants = []
    
    for _ in range(simulations):
        positions = [0]  # Population initiale à l'origine
        traj = [len(positions)]  # Stocke l'évolution de la population
        
        for _ in range(steps):
            new_positions = []
            
            for pos in positions:
                
                if np.random.rand() < alpha:  # Survie
                    new_pos = pos + (1 if np.random.rand() < p else -1)
                    new_positions.append(new_pos)
                    
                    if new_pos == 0:  # Reproduction à l'origine
                        new_positions.append(new_pos)
            
            positions = new_positions  # Mise à jour de la population
            traj.append(len(positions))
            
            if len(positions) == 0:
                break  # Arrêt si toute la population disparaît
        
        survivants.append(traj)
    
    return survivants

def trouver_alpha_critique(p, steps, simulations, precision):
    alpha = 0.5  # Point de départ pour la recherche
    
    while alpha < 1.0:
        survivants = marche_aleatoire(p, alpha, steps, simulations)
        
        if any(len(traj) == steps + 1 and traj[-1] > 0 for traj in survivants): # Il existe au moins une population qui a survécu
            return alpha
        
        alpha += precision  # Augmente alpha progressivement
    
    return 1.0  # Si aucune valeur trouvée, alpha critique est 1.0

# %%
# Paramètres
p = 0.5
steps = 1000
simulations = 1000
precision = 0.001

alpha_c = trouver_alpha_critique(p, steps, simulations, precision)
print(f"p = {p:.3f} -> alpha_critique = {alpha_c:.3f}")
# Out:
# p = 0.500 -> alpha_critique = 0.864

# %%
# Paramètres
steps = 5000
simulations = 100
precision = 0.001

# Valeurs de p à tester
p_values = np.linspace(0.5, 1.0, 21)
alpha_critiques = []

# Calcul des alpha critiques pour chaque p
for p in p_values:
    alpha_c = trouver_alpha_critique(p, steps, simulations, precision)
    alpha_critiques.append(alpha_c)
    print(f"p = {p:.3f} -> alpha_critique = {alpha_c:.3f}")

# Tracé de la courbe
plt.figure(figsize=(10, 6))
plt.plot(p_values, alpha_critiques, 'o-', label='α critique')
plt.xlabel('Probabilité p de mouvement vers la droite')
plt.ylabel('α critique')
plt.title('Valeur critique de α en fonction de p')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# p = 0.500 -> alpha_critique = 0.867
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_33655/3025432222.py in <module>
#      10 # Calcul des alpha critiques pour chaque p
#      11 for p in p_values:
# ---> 12     alpha_c = trouver_alpha_critique(p, steps, simulations, precision)
#      13     alpha_critiques.append(alpha_c)
#      14     print(f"p = {p:.3f} -> alpha_critique = {alpha_c:.3f}")
#
# /tmp/ipykernel_33655/617698499.py in trouver_alpha_critique(p, steps, simulations, precision)
#      35
#      36     while alpha < 1.0:
# ---> 37         survivants = marche_aleatoire(p, alpha, steps, simulations)
#      38
#      39         if any(len(traj) == steps + 1 and traj[-1] > 0 for traj in survivants): # Il existe au moins une population qui a survécu
#
# /tmp/ipykernel_33655/617698499.py in marche_aleatoire(p, alpha, steps, simulations)
#      16                 if np.random.rand() < alpha:  # Survie
#      17                     new_pos = pos + (1 if np.random.rand() < p else -1)
# ---> 18                     new_positions.append(new_pos)
#      19
#      20                     if new_pos == 0:  # Reproduction à l'origine
#
# KeyboardInterrupt:

# %%
# Paramètres
p = 0.5
alpha = 0.90
steps = 1000
simulations = 1000

# Étude de la probabilité de survie
proba = proba_survie(p, alpha, steps, simulations)
print(f"Alpha = {alpha:.3f}, Probabilité de survie = {proba:.3f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8000/1415909883.py in <module>
#       6
#       7 # Étude de la probabilité de survie
# ----> 8 proba = proba_survie(p, alpha, steps, simulations)
#       9 print(f"Alpha = {alpha:.3f}, Probabilité de survie = {proba:.3f}")
#
# /tmp/ipykernel_8000/103564212.py in proba_survie(p, alpha, steps, simulations)
#      12     - Probabilité de survie (proportion de simulations où la population survit jusqu'à 'steps' étapes)
#      13     """
# ---> 14     survivants = marche_aleatoire(p, alpha, steps, simulations)
#      15     taux_survie = np.mean([len(traj) == steps + 1 and traj[-1] > 0 for traj in survivants])
#      16     return taux_survie
#
# /tmp/ipykernel_8000/152621400.py in marche_aleatoire(p, alpha, steps, simulations)
#      26                 if np.random.rand() < alpha:  # Survie (alpha est la proba de survie)
#      27                     new_pos = pos + (1 if np.random.rand() < p else -1)
# ---> 28                     new_positions.append(new_pos)
#      29
#      30                     if new_pos == 0:  # Reproduction à l'origine
#
# KeyboardInterrupt:

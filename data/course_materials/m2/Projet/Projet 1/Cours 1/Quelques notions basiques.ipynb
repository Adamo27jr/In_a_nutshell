# %% [markdown]
# # Les bases de Python

# %% [markdown]
# ## Hello World

# %%
# Afficher Hello World

# Afficher la documentation de la fonction utilisée

# Afficher les fichiers dans le répertoire courant

# %% [markdown]
# ## Une liste

# %% [markdown]
# - Créer une liste vide.
# - Créer une liste d'une suite de chiffre de 0 à 9.
# - Créer une liste de 1 à 10, avec un écart de trois entre chaque élément
# - Imprimer le résultat à chaque fois.

# %%
# Créer une liste vide

# Une liste de 0 à 9

# Une liste de 1 à 10 avec un écart de 3

# %% [markdown]
# ## Une boucle et une fonction

# %% [markdown]
# - Faire une boucle qui créé une liste comprenant les carrés de 0 à 20,
# - En faire une fonction prenant en argumant le nombre de carré à calculer.

# %%
# boucle for

# function carré

# %% [markdown]
# Mesurer le temps pour renvoyer le carré par fonction programmée par boucle et la comparer avec le temps nécessaire pour faire la même chose avec une liste en compréhension.

# %% [markdown]
# ## Types

# %% [markdown]
# - Vérifier le type de la dernière liste créée
# - Le type du quatrième élément
# - Créer une liste de compréhension dont les éléments seront les éléments de la dernière liste convertis en string
# - Créer une liste d'un élément booléen, d'un string, d'un entier et d'un décimal

# %%
# Type de l

# Type du quatrième élément d l

# Création d'une liste de string en compéhension

# Liste hétérogène
